# %%
from pathlib import Path
import pandas as pd
path_df_ocorrencias = Path("dados") / "ocorrencias.json"
df_ocorrencias = pd.read_json(path_df_ocorrencias)
pd.set_option("display.expand_frame_repr", False)
df_ocorrencias
# Out:
# Ocorrencias
# 1. Cadastrar Ocorrencia
# 2. Filtro de Ocorrencias
# 3. Todas as Ocorrencias

# %%
df_ocorrencias["data"] = pd.to_datetime(df_ocorrencias["data"], format="%d/%m/%Y %H:%M:%S")
display(df_ocorrencias["tipo"].unique())
# Out:
# <StringArray>
# [          'Roubo',           'Furto',        'Acidente',        'Incêndio',
#       'Vandalismo',        'Agressão', 'Desaparecimento',         'Tráfico']
# Length: 8, dtype: str
